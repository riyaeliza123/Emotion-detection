# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
from keras.layers import Activation, Dropout, Convolution2D, GlobalAveragePooling2D
from keras.models import Sequential
import tensorflow as tf
import tensorflow.keras.applications.mobilenet
import os

# %%
IMG_SAVE_PATH = r'C:\Users\hp\testing_data_final\train'

# %%
Str_to_Int = {
    'Neutral': 0,
    'Happy': 1,
    'Sad': 2,
    'Scared': 3,
    'Agony': 4
}

NUM_CLASSES = 5


def str_to_Int_mapper(val):
    return Str_to_Int[val]

# %% [markdown]
# ## Model Architecture

# %%
def get_model():
    model = Sequential([
        tf.keras.applications.mobilenet.MobileNet(input_shape=(240, 240, 3), include_top=False),
        Dropout(0.5),
        Convolution2D(5, (1, 1), padding='valid'),
        Activation('relu'),        # Rectified Linear Unit - Activation Function
        GlobalAveragePooling2D(),  # Pooling Layer
        Activation('softmax')      # Softmax - Activation Function - For Multi Class Classification
    ])
    return model

# %%
import PIL

dataset = []
for directory in os.listdir(IMG_SAVE_PATH):
    path = os.path.join(IMG_SAVE_PATH, directory)
    for image in os.listdir(path):
        new_path = os.path.join(path, image)
        img = np.asarray(PIL.Image.open(new_path))
        dataset.append([img, directory])

# %%
dataset
# Out:
# [[array([[[226, 212, 212],
#           [225, 211, 211],
#           [224, 210, 210],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[228, 214, 214],
#           [227, 213, 213],
#           [226, 212, 212],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          [[229, 215, 215],
#           [229, 215, 215],
#           [228, 214, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          ...,
#
#          [[ 78,  54,  52],
#           [ 76,  52,  50],
#           [ 70,  49,  46],
#           ...,
#           [ 77,  65,  75],
#           [ 83,  71,  81],
#           [ 88,  76,  86]],
#
#          [[ 72,  51,  48],
#           [ 70,  49,  46],
#           [ 67,  46,  43],
#           ...,
#           [ 76,  64,  74],
#           [ 82,  70,  80],
#           [ 86,  74,  84]],
#
#          [[ 67,  46,  43],
#           [ 66,  45,  42],
#           [ 65,  44,  41],
#           ...,
#           [ 75,  63,  73],
#           [ 80,  68,  78],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[226, 212, 212],
#           [225, 211, 211],
#           [224, 210, 210],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[228, 214, 214],
#           [227, 213, 213],
#           [226, 212, 212],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          [[229, 215, 215],
#           [229, 215, 215],
#           [228, 214, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          ...,
#
#          [[ 78,  54,  52],
#           [ 76,  52,  50],
#           [ 70,  49,  46],
#           ...,
#           [ 77,  65,  75],
#           [ 83,  71,  81],
#           [ 88,  76,  86]],
#
#          [[ 72,  51,  48],
#           [ 70,  49,  46],
#           [ 67,  46,  43],
#           ...,
#           [ 76,  64,  74],
#           [ 82,  70,  80],
#           [ 86,  74,  84]],
#
#          [[ 67,  46,  43],
#           [ 66,  45,  42],
#           [ 65,  44,  41],
#           ...,
#           [ 75,  63,  73],
#           [ 80,  68,  78],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[226, 212, 212],
#           [225, 211, 211],
#           [224, 210, 210],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[228, 214, 214],
#           [227, 213, 213],
#           [226, 212, 212],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          [[229, 215, 215],
#           [229, 215, 215],
#           [228, 214, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          ...,
#
#          [[ 78,  54,  52],
#           [ 76,  52,  50],
#           [ 70,  49,  46],
#           ...,
#           [ 77,  65,  75],
#           [ 83,  71,  81],
#           [ 88,  76,  86]],
#
#          [[ 72,  51,  48],
#           [ 70,  49,  46],
#           [ 67,  46,  43],
#           ...,
#           [ 76,  64,  74],
#           [ 82,  70,  80],
#           [ 86,  74,  84]],
#
#          [[ 67,  46,  43],
#           [ 66,  45,  42],
#           [ 65,  44,  41],
#           ...,
#           [ 75,  63,  73],
#           [ 80,  68,  78],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [233, 217, 217]],
#
#          [[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          [[224, 209, 212],
#           [225, 210, 213],
#           [225, 210, 213],
#           ...,
#           [237, 221, 221],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          ...,
#
#          [[ 78,  52,  51],
#           [ 77,  51,  50],
#           [ 75,  49,  48],
#           ...,
#           [ 75,  64,  70],
#           [ 82,  71,  77],
#           [ 88,  77,  83]],
#
#          [[ 73,  47,  46],
#           [ 72,  46,  45],
#           [ 70,  44,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 87,  76,  82]],
#
#          [[ 70,  44,  43],
#           [ 69,  43,  42],
#           [ 67,  41,  40],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 86,  75,  81]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [233, 217, 217]],
#
#          [[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          [[224, 209, 212],
#           [225, 210, 213],
#           [225, 210, 213],
#           ...,
#           [237, 221, 221],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          ...,
#
#          [[ 78,  52,  51],
#           [ 77,  51,  50],
#           [ 75,  49,  48],
#           ...,
#           [ 75,  64,  70],
#           [ 82,  71,  77],
#           [ 88,  77,  83]],
#
#          [[ 73,  47,  46],
#           [ 72,  46,  45],
#           [ 70,  44,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 87,  76,  82]],
#
#          [[ 70,  44,  43],
#           [ 69,  43,  42],
#           [ 67,  41,  40],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 86,  75,  81]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [233, 217, 217]],
#
#          [[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          [[224, 209, 212],
#           [225, 210, 213],
#           [225, 210, 213],
#           ...,
#           [237, 221, 221],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          ...,
#
#          [[ 78,  52,  51],
#           [ 77,  51,  50],
#           [ 75,  49,  48],
#           ...,
#           [ 75,  64,  70],
#           [ 82,  71,  77],
#           [ 88,  77,  83]],
#
#          [[ 73,  47,  46],
#           [ 72,  46,  45],
#           [ 70,  44,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 87,  76,  82]],
#
#          [[ 70,  44,  43],
#           [ 69,  43,  42],
#           [ 67,  41,  40],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 86,  75,  81]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [233, 217, 217]],
#
#          [[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          [[224, 209, 212],
#           [225, 210, 213],
#           [225, 210, 213],
#           ...,
#           [237, 221, 221],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          ...,
#
#          [[ 78,  52,  51],
#           [ 77,  51,  50],
#           [ 75,  49,  48],
#           ...,
#           [ 75,  64,  70],
#           [ 82,  71,  77],
#           [ 88,  77,  83]],
#
#          [[ 73,  47,  46],
#           [ 72,  46,  45],
#           [ 70,  44,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 87,  76,  82]],
#
#          [[ 70,  44,  43],
#           [ 69,  43,  42],
#           [ 67,  41,  40],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 86,  75,  81]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [233, 217, 217]],
#
#          [[224, 209, 212],
#           [224, 209, 212],
#           [225, 210, 213],
#           ...,
#           [236, 220, 220],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          [[224, 209, 212],
#           [225, 210, 213],
#           [225, 210, 213],
#           ...,
#           [237, 221, 221],
#           [235, 219, 219],
#           [234, 218, 218]],
#
#          ...,
#
#          [[ 78,  52,  51],
#           [ 77,  51,  50],
#           [ 75,  49,  48],
#           ...,
#           [ 75,  64,  70],
#           [ 82,  71,  77],
#           [ 88,  77,  83]],
#
#          [[ 73,  47,  46],
#           [ 72,  46,  45],
#           [ 70,  44,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 87,  76,  82]],
#
#          [[ 70,  44,  43],
#           [ 69,  43,  42],
#           [ 67,  41,  40],
#           ...,
#           [ 74,  63,  69],
#           [ 81,  70,  76],
#           [ 86,  75,  81]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [238, 223, 220],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[224, 212, 216],
#           [224, 212, 216],
#           [223, 211, 215],
#           ...,
#           [236, 221, 218],
#           [235, 220, 217],
#           [234, 219, 216]],
#
#          ...,
#
#          [[ 79,  49,  47],
#           [ 77,  49,  46],
#           [ 75,  47,  44],
#           ...,
#           [ 75,  62,  72],
#           [ 82,  69,  79],
#           [ 90,  76,  89]],
#
#          [[ 75,  45,  43],
#           [ 73,  45,  42],
#           [ 72,  44,  43],
#           ...,
#           [ 73,  60,  70],
#           [ 80,  67,  77],
#           [ 87,  74,  84]],
#
#          [[ 72,  44,  41],
#           [ 71,  43,  42],
#           [ 70,  42,  41],
#           ...,
#           [ 72,  59,  69],
#           [ 78,  65,  75],
#           [ 86,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [238, 223, 220],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[224, 212, 216],
#           [224, 212, 216],
#           [223, 211, 215],
#           ...,
#           [236, 221, 218],
#           [235, 220, 217],
#           [234, 219, 216]],
#
#          ...,
#
#          [[ 79,  49,  47],
#           [ 77,  49,  46],
#           [ 75,  47,  44],
#           ...,
#           [ 75,  62,  72],
#           [ 82,  69,  79],
#           [ 90,  76,  89]],
#
#          [[ 75,  45,  43],
#           [ 73,  45,  42],
#           [ 72,  44,  43],
#           ...,
#           [ 73,  60,  70],
#           [ 80,  67,  77],
#           [ 87,  74,  84]],
#
#          [[ 72,  44,  41],
#           [ 71,  43,  42],
#           [ 70,  42,  41],
#           ...,
#           [ 72,  59,  69],
#           [ 78,  65,  75],
#           [ 86,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [238, 223, 220],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[224, 212, 216],
#           [224, 212, 216],
#           [223, 211, 215],
#           ...,
#           [236, 221, 218],
#           [235, 220, 217],
#           [234, 219, 216]],
#
#          ...,
#
#          [[ 79,  49,  47],
#           [ 77,  49,  46],
#           [ 75,  47,  44],
#           ...,
#           [ 75,  62,  72],
#           [ 82,  69,  79],
#           [ 90,  76,  89]],
#
#          [[ 75,  45,  43],
#           [ 73,  45,  42],
#           [ 72,  44,  43],
#           ...,
#           [ 73,  60,  70],
#           [ 80,  67,  77],
#           [ 87,  74,  84]],
#
#          [[ 72,  44,  41],
#           [ 71,  43,  42],
#           [ 70,  42,  41],
#           ...,
#           [ 72,  59,  69],
#           [ 78,  65,  75],
#           [ 86,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [238, 223, 220],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[224, 212, 216],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[224, 212, 216],
#           [224, 212, 216],
#           [223, 211, 215],
#           ...,
#           [236, 221, 218],
#           [235, 220, 217],
#           [234, 219, 216]],
#
#          ...,
#
#          [[ 79,  49,  47],
#           [ 77,  49,  46],
#           [ 75,  47,  44],
#           ...,
#           [ 75,  62,  72],
#           [ 82,  69,  79],
#           [ 90,  76,  89]],
#
#          [[ 75,  45,  43],
#           [ 73,  45,  42],
#           [ 72,  44,  43],
#           ...,
#           [ 73,  60,  70],
#           [ 80,  67,  77],
#           [ 87,  74,  84]],
#
#          [[ 72,  44,  41],
#           [ 71,  43,  42],
#           [ 70,  42,  41],
#           ...,
#           [ 72,  59,  69],
#           [ 78,  65,  75],
#           [ 86,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[222, 210, 214],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [238, 223, 220],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[223, 211, 215],
#           [223, 211, 215],
#           [222, 210, 214],
#           ...,
#           [236, 221, 218],
#           [235, 220, 217],
#           [234, 219, 216]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[229, 217, 217],
#           [228, 216, 216],
#           [226, 214, 214],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[221, 209, 211],
#           [221, 209, 211],
#           [221, 209, 211],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[217, 205, 207],
#           [217, 205, 207],
#           [218, 206, 208],
#           ...,
#           [235, 220, 213],
#           [236, 221, 214],
#           [236, 221, 214]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[229, 217, 217],
#           [228, 216, 216],
#           [226, 214, 214],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[221, 209, 211],
#           [221, 209, 211],
#           [221, 209, 211],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[217, 205, 207],
#           [217, 205, 207],
#           [218, 206, 208],
#           ...,
#           [235, 220, 213],
#           [236, 221, 214],
#           [236, 221, 214]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[229, 217, 217],
#           [228, 216, 216],
#           [226, 214, 214],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[221, 209, 211],
#           [221, 209, 211],
#           [221, 209, 211],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[217, 205, 207],
#           [217, 205, 207],
#           [218, 206, 208],
#           ...,
#           [235, 220, 213],
#           [236, 221, 214],
#           [236, 221, 214]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[229, 217, 217],
#           [228, 216, 216],
#           [226, 214, 214],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[221, 209, 211],
#           [221, 209, 211],
#           [221, 209, 211],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[217, 205, 207],
#           [217, 205, 207],
#           [218, 206, 208],
#           ...,
#           [235, 220, 213],
#           [236, 221, 214],
#           [236, 221, 214]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[229, 217, 217],
#           [228, 216, 216],
#           [226, 214, 214],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[221, 209, 211],
#           [221, 209, 211],
#           [221, 209, 211],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [236, 221, 214]],
#
#          [[217, 205, 207],
#           [217, 205, 207],
#           [218, 206, 208],
#           ...,
#           [235, 220, 213],
#           [236, 221, 214],
#           [236, 221, 214]],
#
#          ...,
#
#          [[ 76,  51,  46],
#           [ 75,  50,  45],
#           [ 74,  49,  44],
#           ...,
#           [ 74,  63,  71],
#           [ 82,  71,  79],
#           [ 88,  77,  85]],
#
#          [[ 73,  48,  41],
#           [ 72,  47,  40],
#           [ 71,  46,  39],
#           ...,
#           [ 74,  63,  71],
#           [ 80,  69,  77],
#           [ 85,  74,  82]],
#
#          [[ 71,  46,  39],
#           [ 70,  45,  38],
#           [ 69,  44,  37],
#           ...,
#           [ 74,  63,  71],
#           [ 79,  68,  76],
#           [ 83,  72,  80]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 210, 219],
#           [223, 210, 219],
#           [224, 211, 220],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[221, 208, 217],
#           [221, 208, 217],
#           [222, 209, 218],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[220, 207, 214],
#           [220, 207, 214],
#           [220, 207, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 79,  50,  46],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 84,  77,  84]],
#
#          [[ 73,  44,  38],
#           [ 72,  45,  38],
#           [ 71,  44,  37],
#           ...,
#           [ 70,  63,  70],
#           [ 78,  71,  78],
#           [ 84,  77,  84]],
#
#          [[ 68,  41,  34],
#           [ 68,  41,  34],
#           [ 68,  41,  34],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 85,  78,  85]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 210, 219],
#           [223, 210, 219],
#           [224, 211, 220],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[221, 208, 217],
#           [221, 208, 217],
#           [222, 209, 218],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[220, 207, 214],
#           [220, 207, 214],
#           [220, 207, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 79,  50,  46],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 84,  77,  84]],
#
#          [[ 73,  44,  38],
#           [ 72,  45,  38],
#           [ 71,  44,  37],
#           ...,
#           [ 70,  63,  70],
#           [ 78,  71,  78],
#           [ 84,  77,  84]],
#
#          [[ 68,  41,  34],
#           [ 68,  41,  34],
#           [ 68,  41,  34],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 85,  78,  85]]], dtype=uint8),
#   'Agony'],
#  [array([[[144, 132, 136],
#           [145, 133, 137],
#           [147, 135, 139],
#           ...,
#           [151, 146, 152],
#           [152, 147, 153],
#           [152, 147, 153]],
#
#          [[145, 133, 137],
#           [145, 133, 137],
#           [146, 134, 138],
#           ...,
#           [151, 146, 152],
#           [152, 147, 153],
#           [153, 148, 154]],
#
#          [[145, 133, 137],
#           [145, 133, 137],
#           [146, 134, 138],
#           ...,
#           [152, 147, 153],
#           [153, 148, 154],
#           [154, 149, 155]],
#
#          ...,
#
#          [[ 76,  56,  47],
#           [ 86,  66,  57],
#           [ 95,  73,  62],
#           ...,
#           [160, 133, 122],
#           [165, 136, 122],
#           [166, 137, 121]],
#
#          [[ 76,  56,  47],
#           [ 88,  65,  57],
#           [ 96,  72,  62],
#           ...,
#           [162, 135, 124],
#           [163, 135, 121],
#           [162, 133, 117]],
#
#          [[ 79,  56,  48],
#           [ 88,  65,  57],
#           [ 96,  72,  62],
#           ...,
#           [164, 137, 126],
#           [164, 136, 122],
#           [162, 133, 117]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 210, 219],
#           [223, 210, 219],
#           [224, 211, 220],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[221, 208, 217],
#           [221, 208, 217],
#           [222, 209, 218],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[220, 207, 214],
#           [220, 207, 214],
#           [220, 207, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 79,  50,  46],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 84,  77,  84]],
#
#          [[ 73,  44,  38],
#           [ 72,  45,  38],
#           [ 71,  44,  37],
#           ...,
#           [ 70,  63,  70],
#           [ 78,  71,  78],
#           [ 84,  77,  84]],
#
#          [[ 68,  41,  34],
#           [ 68,  41,  34],
#           [ 68,  41,  34],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 85,  78,  85]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 210, 219],
#           [223, 210, 219],
#           [224, 211, 220],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[221, 208, 217],
#           [221, 208, 217],
#           [222, 209, 218],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[220, 207, 214],
#           [220, 207, 214],
#           [220, 207, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 79,  50,  46],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 84,  77,  84]],
#
#          [[ 73,  44,  38],
#           [ 72,  45,  38],
#           [ 71,  44,  37],
#           ...,
#           [ 70,  63,  70],
#           [ 78,  71,  78],
#           [ 84,  77,  84]],
#
#          [[ 68,  41,  34],
#           [ 68,  41,  34],
#           [ 68,  41,  34],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 85,  78,  85]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 210, 219],
#           [223, 210, 219],
#           [224, 211, 220],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[221, 208, 217],
#           [221, 208, 217],
#           [222, 209, 218],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          [[220, 207, 214],
#           [220, 207, 214],
#           [220, 207, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 79,  50,  46],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 84,  77,  84]],
#
#          [[ 73,  44,  38],
#           [ 72,  45,  38],
#           [ 71,  44,  37],
#           ...,
#           [ 70,  63,  70],
#           [ 78,  71,  78],
#           [ 84,  77,  84]],
#
#          [[ 68,  41,  34],
#           [ 68,  41,  34],
#           [ 68,  41,  34],
#           ...,
#           [ 71,  64,  71],
#           [ 79,  72,  79],
#           [ 85,  78,  85]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[223, 211, 215],
#           [223, 211, 215],
#           [224, 212, 216],
#           ...,
#           [235, 220, 217],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[222, 210, 214],
#           [223, 211, 215],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [238, 223, 220]],
#
#          [[221, 209, 213],
#           [222, 210, 214],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [238, 223, 220],
#           [238, 223, 220]],
#
#          ...,
#
#          [[ 79,  51,  50],
#           [ 78,  50,  49],
#           [ 77,  49,  48],
#           ...,
#           [ 75,  63,  73],
#           [ 82,  70,  80],
#           [ 90,  78,  88]],
#
#          [[ 74,  46,  45],
#           [ 74,  46,  45],
#           [ 73,  45,  44],
#           ...,
#           [ 73,  61,  71],
#           [ 79,  67,  77],
#           [ 87,  75,  85]],
#
#          [[ 71,  42,  44],
#           [ 70,  41,  43],
#           [ 70,  41,  43],
#           ...,
#           [ 72,  60,  70],
#           [ 77,  65,  75],
#           [ 85,  73,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 215],
#           [225, 213, 215],
#           [224, 212, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[224, 212, 214],
#           [224, 212, 214],
#           [223, 211, 213],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          [[223, 211, 213],
#           [222, 210, 212],
#           [222, 210, 212],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 80,  52,  48],
#           [ 79,  51,  47],
#           [ 77,  49,  45],
#           ...,
#           [ 71,  63,  76],
#           [ 78,  70,  83],
#           [ 83,  75,  88]],
#
#          [[ 76,  49,  42],
#           [ 75,  48,  41],
#           [ 73,  46,  39],
#           ...,
#           [ 69,  61,  74],
#           [ 75,  67,  80],
#           [ 81,  73,  86]],
#
#          [[ 70,  43,  36],
#           [ 69,  42,  35],
#           [ 68,  41,  34],
#           ...,
#           [ 67,  59,  72],
#           [ 74,  66,  79],
#           [ 79,  71,  84]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 215],
#           [225, 213, 215],
#           [224, 212, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[224, 212, 214],
#           [224, 212, 214],
#           [223, 211, 213],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          [[223, 211, 213],
#           [222, 210, 212],
#           [222, 210, 212],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 80,  52,  48],
#           [ 79,  51,  47],
#           [ 77,  49,  45],
#           ...,
#           [ 71,  63,  76],
#           [ 78,  70,  83],
#           [ 83,  75,  88]],
#
#          [[ 76,  49,  42],
#           [ 75,  48,  41],
#           [ 73,  46,  39],
#           ...,
#           [ 69,  61,  74],
#           [ 75,  67,  80],
#           [ 81,  73,  86]],
#
#          [[ 70,  43,  36],
#           [ 69,  42,  35],
#           [ 68,  41,  34],
#           ...,
#           [ 67,  59,  72],
#           [ 74,  66,  79],
#           [ 79,  71,  84]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 215],
#           [225, 213, 215],
#           [224, 212, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[224, 212, 214],
#           [224, 212, 214],
#           [223, 211, 213],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          [[223, 211, 213],
#           [222, 210, 212],
#           [222, 210, 212],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 80,  52,  48],
#           [ 79,  51,  47],
#           [ 77,  49,  45],
#           ...,
#           [ 71,  63,  76],
#           [ 78,  70,  83],
#           [ 83,  75,  88]],
#
#          [[ 76,  49,  42],
#           [ 75,  48,  41],
#           [ 73,  46,  39],
#           ...,
#           [ 69,  61,  74],
#           [ 75,  67,  80],
#           [ 81,  73,  86]],
#
#          [[ 70,  43,  36],
#           [ 69,  42,  35],
#           [ 68,  41,  34],
#           ...,
#           [ 67,  59,  72],
#           [ 74,  66,  79],
#           [ 79,  71,  84]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 215],
#           [225, 213, 215],
#           [224, 212, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[224, 212, 214],
#           [224, 212, 214],
#           [223, 211, 213],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          [[223, 211, 213],
#           [222, 210, 212],
#           [222, 210, 212],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 80,  52,  48],
#           [ 79,  51,  47],
#           [ 77,  49,  45],
#           ...,
#           [ 71,  63,  76],
#           [ 78,  70,  83],
#           [ 83,  75,  88]],
#
#          [[ 76,  49,  42],
#           [ 75,  48,  41],
#           [ 73,  46,  39],
#           ...,
#           [ 69,  61,  74],
#           [ 75,  67,  80],
#           [ 81,  73,  86]],
#
#          [[ 70,  43,  36],
#           [ 69,  42,  35],
#           [ 68,  41,  34],
#           ...,
#           [ 67,  59,  72],
#           [ 74,  66,  79],
#           [ 79,  71,  84]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 215],
#           [225, 213, 215],
#           [224, 212, 214],
#           ...,
#           [236, 221, 218],
#           [236, 221, 218],
#           [236, 221, 218]],
#
#          [[224, 212, 214],
#           [224, 212, 214],
#           [223, 211, 213],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          [[223, 211, 213],
#           [222, 210, 212],
#           [222, 210, 212],
#           ...,
#           [235, 220, 217],
#           [235, 220, 217],
#           [235, 220, 217]],
#
#          ...,
#
#          [[ 80,  52,  48],
#           [ 79,  51,  47],
#           [ 77,  49,  45],
#           ...,
#           [ 71,  63,  76],
#           [ 78,  70,  83],
#           [ 83,  75,  88]],
#
#          [[ 76,  49,  42],
#           [ 75,  48,  41],
#           [ 73,  46,  39],
#           ...,
#           [ 69,  61,  74],
#           [ 75,  67,  80],
#           [ 81,  73,  86]],
#
#          [[ 70,  43,  36],
#           [ 69,  42,  35],
#           [ 68,  41,  34],
#           ...,
#           [ 67,  59,  72],
#           [ 74,  66,  79],
#           [ 79,  71,  84]]], dtype=uint8),
#   'Agony'],
#  [array([[[227, 215, 219],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[226, 214, 218],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[225, 213, 217],
#           [225, 213, 217],
#           [224, 212, 216],
#           ...,
#           [236, 221, 214],
#           [235, 220, 213],
#           [235, 220, 213]],
#
#          ...,
#
#          [[ 81,  50,  48],
#           [ 80,  49,  47],
#           [ 78,  48,  46],
#           ...,
#           [ 76,  65,  71],
#           [ 85,  74,  80],
#           [ 91,  80,  86]],
#
#          [[ 79,  48,  46],
#           [ 77,  47,  45],
#           [ 75,  45,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 83,  72,  78],
#           [ 89,  78,  84]],
#
#          [[ 78,  47,  45],
#           [ 76,  46,  44],
#           [ 74,  44,  42],
#           ...,
#           [ 73,  62,  68],
#           [ 81,  70,  76],
#           [ 88,  77,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[227, 215, 219],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[226, 214, 218],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[225, 213, 217],
#           [225, 213, 217],
#           [224, 212, 216],
#           ...,
#           [236, 221, 214],
#           [235, 220, 213],
#           [235, 220, 213]],
#
#          ...,
#
#          [[ 81,  50,  48],
#           [ 80,  49,  47],
#           [ 78,  48,  46],
#           ...,
#           [ 76,  65,  71],
#           [ 85,  74,  80],
#           [ 91,  80,  86]],
#
#          [[ 79,  48,  46],
#           [ 77,  47,  45],
#           [ 75,  45,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 83,  72,  78],
#           [ 89,  78,  84]],
#
#          [[ 78,  47,  45],
#           [ 76,  46,  44],
#           [ 74,  44,  42],
#           ...,
#           [ 73,  62,  68],
#           [ 81,  70,  76],
#           [ 88,  77,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[227, 215, 219],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[226, 214, 218],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[225, 213, 217],
#           [225, 213, 217],
#           [224, 212, 216],
#           ...,
#           [236, 221, 214],
#           [235, 220, 213],
#           [235, 220, 213]],
#
#          ...,
#
#          [[ 81,  50,  48],
#           [ 80,  49,  47],
#           [ 78,  48,  46],
#           ...,
#           [ 76,  65,  71],
#           [ 85,  74,  80],
#           [ 91,  80,  86]],
#
#          [[ 79,  48,  46],
#           [ 77,  47,  45],
#           [ 75,  45,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 83,  72,  78],
#           [ 89,  78,  84]],
#
#          [[ 78,  47,  45],
#           [ 76,  46,  44],
#           [ 74,  44,  42],
#           ...,
#           [ 73,  62,  68],
#           [ 81,  70,  76],
#           [ 88,  77,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[227, 215, 219],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[226, 214, 218],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[225, 213, 217],
#           [225, 213, 217],
#           [224, 212, 216],
#           ...,
#           [236, 221, 214],
#           [235, 220, 213],
#           [235, 220, 213]],
#
#          ...,
#
#          [[ 81,  50,  48],
#           [ 80,  49,  47],
#           [ 78,  48,  46],
#           ...,
#           [ 76,  65,  71],
#           [ 85,  74,  80],
#           [ 91,  80,  86]],
#
#          [[ 79,  48,  46],
#           [ 77,  47,  45],
#           [ 75,  45,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 83,  72,  78],
#           [ 89,  78,  84]],
#
#          [[ 78,  47,  45],
#           [ 76,  46,  44],
#           [ 74,  44,  42],
#           ...,
#           [ 73,  62,  68],
#           [ 81,  70,  76],
#           [ 88,  77,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[227, 215, 219],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[226, 214, 218],
#           [226, 214, 218],
#           [225, 213, 217],
#           ...,
#           [235, 220, 213],
#           [235, 220, 213],
#           [234, 219, 212]],
#
#          [[225, 213, 217],
#           [225, 213, 217],
#           [224, 212, 216],
#           ...,
#           [236, 221, 214],
#           [235, 220, 213],
#           [235, 220, 213]],
#
#          ...,
#
#          [[ 81,  50,  48],
#           [ 80,  49,  47],
#           [ 78,  48,  46],
#           ...,
#           [ 76,  65,  71],
#           [ 85,  74,  80],
#           [ 91,  80,  86]],
#
#          [[ 79,  48,  46],
#           [ 77,  47,  45],
#           [ 75,  45,  43],
#           ...,
#           [ 74,  63,  69],
#           [ 83,  72,  78],
#           [ 89,  78,  84]],
#
#          [[ 78,  47,  45],
#           [ 76,  46,  44],
#           [ 74,  44,  42],
#           ...,
#           [ 73,  62,  68],
#           [ 81,  70,  76],
#           [ 88,  77,  83]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 217],
#           [224, 212, 216],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[226, 214, 218],
#           [225, 213, 217],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          [[227, 215, 219],
#           [226, 214, 218],
#           [224, 212, 216],
#           ...,
#           [236, 221, 218],
#           [238, 223, 220],
#           [239, 224, 221]],
#
#          ...,
#
#          [[ 80,  51,  47],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 75,  62,  69],
#           [ 82,  69,  76],
#           [ 91,  78,  85]],
#
#          [[ 75,  46,  40],
#           [ 73,  45,  41],
#           [ 71,  43,  39],
#           ...,
#           [ 74,  61,  68],
#           [ 81,  68,  75],
#           [ 89,  76,  83]],
#
#          [[ 72,  45,  38],
#           [ 70,  43,  36],
#           [ 69,  41,  37],
#           ...,
#           [ 73,  60,  67],
#           [ 80,  67,  74],
#           [ 88,  75,  82]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 217],
#           [224, 212, 216],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[226, 214, 218],
#           [225, 213, 217],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          [[227, 215, 219],
#           [226, 214, 218],
#           [224, 212, 216],
#           ...,
#           [236, 221, 218],
#           [238, 223, 220],
#           [239, 224, 221]],
#
#          ...,
#
#          [[ 80,  51,  47],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
#           [ 75,  62,  69],
#           [ 82,  69,  76],
#           [ 91,  78,  85]],
#
#          [[ 75,  46,  40],
#           [ 73,  45,  41],
#           [ 71,  43,  39],
#           ...,
#           [ 74,  61,  68],
#           [ 81,  68,  75],
#           [ 89,  76,  83]],
#
#          [[ 72,  45,  38],
#           [ 70,  43,  36],
#           [ 69,  41,  37],
#           ...,
#           [ 73,  60,  67],
#           [ 80,  67,  74],
#           [ 88,  75,  82]]], dtype=uint8),
#   'Agony'],
#  [array([[[225, 213, 217],
#           [224, 212, 216],
#           [222, 210, 214],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [236, 221, 218]],
#
#          [[226, 214, 218],
#           [225, 213, 217],
#           [223, 211, 215],
#           ...,
#           [237, 222, 219],
#           [237, 222, 219],
#           [237, 222, 219]],
#
#          [[227, 215, 219],
#           [226, 214, 218],
#           [224, 212, 216],
#           ...,
#           [236, 221, 218],
#           [238, 223, 220],
#           [239, 224, 221]],
#
#          ...,
#
#          [[ 80,  51,  47],
#           [ 77,  49,  45],
#           [ 75,  47,  43],
#           ...,
# ...
#
#          [[101,  43,  68],
#           [ 99,  41,  66],
#           [ 97,  39,  64],
#           ...,
#           [ 74,  25,  47],
#           [ 73,  21,  44],
#           [ 72,  20,  43]]], dtype=uint8),
#   'Agony'],
#  [array([[[240, 234, 234],
#           [239, 233, 233],
#           [238, 232, 232],
#           ...,
#           [246, 236, 234],
#           [244, 234, 232],
#           [243, 233, 231]],
#
#          [[241, 235, 235],
#           [240, 234, 234],
#           [239, 233, 233],
#           ...,
#           [246, 236, 234],
#           [245, 235, 233],
#           [244, 234, 232]],
#
#          [[242, 236, 236],
#           [242, 236, 236],
#           [241, 235, 235],
#           ...,
#           [246, 236, 234],
#           [245, 235, 233],
#           [245, 235, 233]],
#
#          ...,
#
#          [[102,  44,  69],
#           [100,  42,  67],
#           [ 98,  40,  65],
#           ...,
#           [ 76,  24,  47],
#           [ 74,  22,  45],
#           [ 73,  21,  44]],
#
#          [[102,  44,  69],
#           [100,  42,  67],
#           [ 97,  39,  64],
#           ...,
#           [ 74,  25,  47],
#           [ 74,  22,  45],
#           [ 72,  20,  43]],
#
#          [[101,  43,  68],
#           [ 99,  41,  66],
#           [ 97,  39,  64],
#           ...,
#           [ 74,  25,  47],
#           [ 73,  21,  44],
#           [ 72,  20,  43]]], dtype=uint8),
#   'Agony'],
#  [array([[[240, 234, 234],
#           [239, 233, 233],
#           [238, 232, 232],
#           ...,
#           [246, 236, 234],
#           [244, 234, 232],
#           [243, 233, 231]],
#
#          [[241, 235, 235],
#           [240, 234, 234],
#           [239, 233, 233],
#           ...,
#           [246, 236, 234],
#           [245, 235, 233],
#           [244, 234, 232]],
#
#          [[242, 236, 236],
#           [242, 236, 236],
#           [241, 235, 235],
#           ...,
#           [246, 236, 234],
#           [245, 235, 233],
#           [245, 235, 233]],
#
#          ...,
#
#          [[102,  44,  69],
#           [100,  42,  67],
#           [ 98,  40,  65],
#           ...,
#           [ 76,  24,  47],
#           [ 74,  22,  45],
#           [ 73,  21,  44]],
#
#          [[102,  44,  69],
#           [100,  42,  67],
#           [ 97,  39,  64],
#           ...,
#           [ 74,  25,  47],
#           [ 74,  22,  45],
#           [ 72,  20,  43]],
#
#          [[101,  43,  68],
#           [ 99,  41,  66],
#           [ 97,  39,  64],
#           ...,
#           [ 74,  25,  47],
#           [ 73,  21,  44],
#           [ 72,  20,  43]]], dtype=uint8),
#   'Agony'],
#  [array([[[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [249, 239, 237],
#           [249, 239, 237],
#           [249, 239, 237]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [248, 238, 236],
#           [248, 238, 236],
#           [247, 237, 235]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [246, 236, 234],
#           [247, 237, 235],
#           [247, 237, 235]],
#
#          ...,
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [103,  45,  67],
#           ...,
#           [ 75,  29,  42],
#           [ 74,  26,  38],
#           [ 73,  25,  37]],
#
#          [[102,  44,  66],
#           [102,  44,  66],
#           [102,  44,  66],
#           ...,
#           [ 73,  27,  40],
#           [ 70,  24,  35],
#           [ 70,  22,  34]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [101,  43,  65],
#           ...,
#           [ 71,  25,  38],
#           [ 68,  22,  33],
#           [ 67,  21,  32]]], dtype=uint8),
#   'Agony'],
#  [array([[[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [249, 239, 237],
#           [249, 239, 237],
#           [249, 239, 237]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [248, 238, 236],
#           [248, 238, 236],
#           [247, 237, 235]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [246, 236, 234],
#           [247, 237, 235],
#           [247, 237, 235]],
#
#          ...,
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [103,  45,  67],
#           ...,
#           [ 75,  29,  42],
#           [ 74,  26,  38],
#           [ 73,  25,  37]],
#
#          [[102,  44,  66],
#           [102,  44,  66],
#           [102,  44,  66],
#           ...,
#           [ 73,  27,  40],
#           [ 70,  24,  35],
#           [ 70,  22,  34]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [101,  43,  65],
#           ...,
#           [ 71,  25,  38],
#           [ 68,  22,  33],
#           [ 67,  21,  32]]], dtype=uint8),
#   'Agony'],
#  [array([[[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [249, 239, 237],
#           [249, 239, 237],
#           [249, 239, 237]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [248, 238, 236],
#           [248, 238, 236],
#           [247, 237, 235]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [246, 236, 234],
#           [247, 237, 235],
#           [247, 237, 235]],
#
#          ...,
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [103,  45,  67],
#           ...,
#           [ 75,  29,  42],
#           [ 74,  26,  38],
#           [ 73,  25,  37]],
#
#          [[102,  44,  66],
#           [102,  44,  66],
#           [102,  44,  66],
#           ...,
#           [ 73,  27,  40],
#           [ 70,  24,  35],
#           [ 70,  22,  34]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [101,  43,  65],
#           ...,
#           [ 71,  25,  38],
#           [ 68,  22,  33],
#           [ 67,  21,  32]]], dtype=uint8),
#   'Agony'],
#  [array([[[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [249, 239, 237],
#           [249, 239, 237],
#           [249, 239, 237]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [248, 238, 236],
#           [248, 238, 236],
#           [247, 237, 235]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [246, 236, 234],
#           [247, 237, 235],
#           [247, 237, 235]],
#
#          ...,
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [103,  45,  67],
#           ...,
#           [ 75,  29,  42],
#           [ 74,  26,  38],
#           [ 73,  25,  37]],
#
#          [[102,  44,  66],
#           [102,  44,  66],
#           [102,  44,  66],
#           ...,
#           [ 73,  27,  40],
#           [ 70,  24,  35],
#           [ 70,  22,  34]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [101,  43,  65],
#           ...,
#           [ 71,  25,  38],
#           [ 68,  22,  33],
#           [ 67,  21,  32]]], dtype=uint8),
#   'Agony'],
#  [array([[[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [249, 239, 237],
#           [249, 239, 237],
#           [249, 239, 237]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [248, 238, 236],
#           [248, 238, 236],
#           [247, 237, 235]],
#
#          [[244, 237, 244],
#           [245, 238, 245],
#           [246, 240, 244],
#           ...,
#           [246, 236, 234],
#           [247, 237, 235],
#           [247, 237, 235]],
#
#          ...,
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [103,  45,  67],
#           ...,
#           [ 75,  29,  42],
#           [ 74,  26,  38],
#           [ 73,  25,  37]],
#
#          [[102,  44,  66],
#           [102,  44,  66],
#           [102,  44,  66],
#           ...,
#           [ 73,  27,  40],
#           [ 70,  24,  35],
#           [ 70,  22,  34]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [101,  43,  65],
#           ...,
#           [ 71,  25,  38],
#           [ 68,  22,  33],
#           [ 67,  21,  32]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  [array([[[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [250, 241, 236],
#           [248, 239, 234],
#           [247, 238, 233]],
#
#          [[246, 241, 238],
#           [245, 240, 237],
#           [243, 238, 235],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          [[245, 239, 239],
#           [244, 238, 238],
#           [244, 238, 238],
#           ...,
#           [249, 240, 235],
#           [248, 239, 234],
#           [248, 239, 234]],
#
#          ...,
#
#          [[105,  47,  69],
#           [104,  46,  68],
#           [103,  45,  67],
#           ...,
#           [ 79,  28,  45],
#           [ 78,  27,  44],
#           [ 78,  27,  44]],
#
#          [[103,  45,  67],
#           [103,  45,  67],
#           [102,  44,  66],
#           ...,
#           [ 75,  27,  43],
#           [ 76,  25,  42],
#           [ 75,  24,  41]],
#
#          [[101,  43,  65],
#           [101,  43,  65],
#           [100,  42,  64],
#           ...,
#           [ 73,  25,  41],
#           [ 73,  22,  39],
#           [ 73,  22,  39]]], dtype=uint8),
#   'Agony'],
#  ...]

# %%
data, labels = zip(*dataset)
temp = list(map(str_to_Int_mapper, labels))

# %%
temp[0]
# Out:
# 4

# %%
# one hot encoding the labels
import keras
labels = keras.utils.to_categorical(temp)

# define the model
model = get_model()
model.compile(
    
    optimizer=Adam(lr=0.0001),         # lr = learning_rate
    loss='categorical_crossentropy',   # Multi-class classification
    metrics=['accuracy']  
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# D:\Sonu\MINE\Mmmm..Personal\Ana\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
print(np.array(data[0].shape))
print(np.array(labels.shape))
# Out:
# [240 240   3]
# [21570     5]

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  dropout (Dropout)           (None, 7, 7, 1024)        0
#
#  conv2d (Conv2D)             (None, 7, 7, 5)           5125
#
#  activation (Activation)     (None, 7, 7, 5)           0
#
#  global_average_pooling2d (G  (None, 5)                0
#  lobalAveragePooling2D)
#
#  activation_1 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 3,233,989
# Trainable params: 3,212,101
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# start training
model.fit(np.array(data), np.array(labels))
# Out:
# 675/675 [==============================] - 1907s 3s/step - loss: 0.0637 - accuracy: 0.9817

# %%
# define the model
model_new = get_model()
model_new.compile(
    optimizer=Adam(lr=0.0001),         # lr = learning_rate
    loss='categorical_crossentropy',   # Multi-class classification
    metrics=['accuracy']  
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# D:\Sonu\MINE\Mmmm..Personal\Ana\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
## EPOCHS + VALIDATION

model_new.fit(np.array(data), np.array(labels), epochs = 5, shuffle = True, validation_split = 0.1)
# Out:
# Epoch 1/5
# 607/607 [==============================] - 1848s 3s/step - loss: 0.0704 - accuracy: 0.9786 - val_loss: 0.6241 - val_accuracy: 0.8183
# Epoch 2/5
# 607/607 [==============================] - 1921s 3s/step - loss: 6.8137e-04 - accuracy: 0.9999 - val_loss: 0.8527 - val_accuracy: 0.7793
# Epoch 3/5
# 607/607 [==============================] - 1978s 3s/step - loss: 2.6184e-04 - accuracy: 1.0000 - val_loss: 0.6682 - val_accuracy: 0.8308
# Epoch 4/5
# 607/607 [==============================] - 1903s 3s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.8922 - val_accuracy: 0.7399
# Epoch 5/5
# 607/607 [==============================] - 1890s 3s/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.5594 - val_accuracy: 0.8507

# %%
# save the model for later use
model.save("face_sentiment_mark3.h5")

# %%
# save the model for later use
model.save("face_sentiment_mark2_train_test.h5")

# %%
IMG_SAVE_PATH_TESTING = r'C:\Users\hp\testing_data_final\test'

# %%
import PIL
# import cv2
dataset_testing = []
for directory in os.listdir(IMG_SAVE_PATH_TESTING):
    path = os.path.join(IMG_SAVE_PATH_TESTING, directory)
    for image in os.listdir(path):
        new_path = os.path.join(path, image)
        img = np.asarray(PIL.Image.open(new_path))
#         img = cv2.imread(new_path)
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         img = cv2.resize(img, (240, 240))
        dataset_testing.append([img, directory])

# %%
testing_data, testing_labels = zip(*dataset)
testing_temp = list(map(str_to_Int_mapper, testing_labels))

# %%
testing_labels = keras.utils.to_categorical(testing_temp)

# %%
model.evaluate(np.array(testing_data), np.array(testing_labels))
# Out:
# 675/675 [==============================] - 426s 618ms/step - loss: 2.9884e-04 - accuracy: 1.0000
# [0.0002988437772728503, 1.0]

# %%
testing_labels[4]
# Out:
# array([0., 0., 0., 0., 1.], dtype=float32)

# %%
labels[4]
# Out:
# array([0., 0., 0., 0., 1.], dtype=float32)

# %%
testing_data[0]
# Out:
# array([[[226, 212, 212],
#         [225, 211, 211],
#         [224, 210, 210],
#         ...,
#         [236, 221, 218],
#         [236, 221, 218],
#         [236, 221, 218]],
#
#        [[228, 214, 214],
#         [227, 213, 213],
#         [226, 212, 212],
#         ...,
#         [237, 222, 219],
#         [238, 223, 220],
#         [238, 223, 220]],
#
#        [[229, 215, 215],
#         [229, 215, 215],
#         [228, 214, 214],
#         ...,
#         [237, 222, 219],
#         [237, 222, 219],
#         [237, 222, 219]],
#
#        ...,
#
#        [[ 78,  54,  52],
#         [ 76,  52,  50],
#         [ 70,  49,  46],
#         ...,
#         [ 77,  65,  75],
#         [ 83,  71,  81],
#         [ 88,  76,  86]],
#
#        [[ 72,  51,  48],
#         [ 70,  49,  46],
#         [ 67,  46,  43],
#         ...,
#         [ 76,  64,  74],
#         [ 82,  70,  80],
#         [ 86,  74,  84]],
#
#        [[ 67,  46,  43],
#         [ 66,  45,  42],
#         [ 65,  44,  41],
#         ...,
#         [ 75,  63,  73],
#         [ 80,  68,  78],
#         [ 85,  73,  83]]], dtype=uint8)

# %%
data[0]
# Out:
# array([[[226, 212, 212],
#         [225, 211, 211],
#         [224, 210, 210],
#         ...,
#         [236, 221, 218],
#         [236, 221, 218],
#         [236, 221, 218]],
#
#        [[228, 214, 214],
#         [227, 213, 213],
#         [226, 212, 212],
#         ...,
#         [237, 222, 219],
#         [238, 223, 220],
#         [238, 223, 220]],
#
#        [[229, 215, 215],
#         [229, 215, 215],
#         [228, 214, 214],
#         ...,
#         [237, 222, 219],
#         [237, 222, 219],
#         [237, 222, 219]],
#
#        ...,
#
#        [[ 78,  54,  52],
#         [ 76,  52,  50],
#         [ 70,  49,  46],
#         ...,
#         [ 77,  65,  75],
#         [ 83,  71,  81],
#         [ 88,  76,  86]],
#
#        [[ 72,  51,  48],
#         [ 70,  49,  46],
#         [ 67,  46,  43],
#         ...,
#         [ 76,  64,  74],
#         [ 82,  70,  80],
#         [ 86,  74,  84]],
#
#        [[ 67,  46,  43],
#         [ 66,  45,  42],
#         [ 65,  44,  41],
#         ...,
#         [ 75,  63,  73],
#         [ 80,  68,  78],
#         [ 85,  73,  83]]], dtype=uint8)
