# %%
import cv2
import os

# %%
cap = cv2.VideoCapture(0)

flag_collecting = False
images_collected = 0
images_required = 50

directory = 'testing_demo'
# os.mkdir(directory)

# %%
while True:
    ret, frame = cap.read()
    frame = cv2.flip(frame, 1)
    
    if images_collected == images_required:
        break

    cv2.rectangle(frame, (200,80),(440,320), (0, 0, 0), 3)

    if flag_collecting == True:
        sliced_frame = frame[80:320,200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))
        cv2.imwrite(save_path, sliced_frame)
        images_collected += 1

    cv2.putText(frame, "Saved Images: {}".format(images_collected), (400, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)
    cv2.imshow("Data Collection", frame)
    
    k = cv2.waitKey(10)
    if k == ord('s'):
        flag_collecting = not flag_collecting
    if k == ord('q'):
        break

print(images_collected, "images saved to directory")
cap.release()
cv2.destroyAllWindows()

# %%
# !pip install pygame

# %%
import pygame
import pygame.camera
from pygame.locals import *

pygame.init()
pygame.camera.init()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
camlist = pygame.camera.list_cameras()
if camlist:
    cam = pygame.camera.Camera(camlist[0],(640,480))

# %%
cam.start()
image = cam.get_image()

# %%
pip install face-recognition
# Out:
# ...
#   Running setup.py clean for dlib
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=55de197d046689c3c97ccb02fc9110b20d2bc0dbe42ede1a57ea14f8e2a443b1
#   Stored in directory: c:\users\sreed\appdata\local\pip\cache\wheels\22\a8\60\4a2aeb763d63f50190f4c4e07069a22245347eeafdb3a67551
# Successfully built face-recognition-models
# Failed to build dlib
# ...
#     Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import pygame
import pygame.camera
from pygame.locals import *

pygame.init()
pygame.camera.init()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class Capture:
    def __init__(self):
        self.size = (640,480)
        # create a display surface. standard pygame stuff
        self.display = pygame.display.set_mode(self.size, 0)

        # this is the same as what we saw before
        self.clist = pygame.camera.list_cameras()
        if not self.clist:
            raise ValueError("Sorry, no cameras detected.")
        self.cam = pygame.camera.Camera(self.clist[0], self.size)
        self.cam.start()

        # create a surface to capture to.  for performance purposes
        # bit depth is the same as that of the display surface.
        self.snapshot = pygame.surface.Surface(self.size, 0, self.display)

    def get_and_flip(self):
        # if you don't want to tie the framerate to the camera, you can check
        # if the camera has an image ready.  note that while this works
        # on most cameras, some will never return true.
        if self.cam.query_image():
            self.snapshot = self.cam.get_image(self.snapshot)

        # blit it to the display surface.  simple!
        self.display.blit(self.snapshot, (0,0))
        pygame.display.flip()

    def main(self):
        going = True
        while going:
            events = pygame.event.get()
            for e in events:
                if e.type == QUIT or (e.type == KEYDOWN and e.key == K_ESCAPE):
                    # close the camera safely
                    self.cam.stop()
                    going = False

            self.get_and_flip()

# %%
import pygame.camera
import pygame.image
import sys
import numpy as np


pygame.camera.init()

cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()
 
# grab first frame
img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pyGame Camera View")
 
while True :
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()

            
    # draw frame
    screen.blit(img, (0,0))
    pygame.display.flip()
    # grab next frame    
    img = webcam.get_image()
    
    print(np.array(img.get_view('3')).shape)
# Out:
# Using camera Integrated Camera ...
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# (640, 480, 3)
# ...

# %%
# !pip install scipy

# %%
# !pip install pynput

# %%
# os.mkdir(directory)

# %%
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#Agony
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 10507
images_required = 10693

directory = 'testing_demo_4\\Sad'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# Using camera Integrated Camera ...
# 10524

# %%
#Happy
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 10773
images_required = 10973
directory = 'testing_demo_4\\Happy'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# Using camera Integrated Camera ...

# %%
#Neutral
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 11118
images_required = 11307
directory = 'testing_demo_4\\Scared'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# Using camera Integrated Camera ...

# %%
#Sad
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 10261
images_required = 10461
directory = 'testing_demo_4\\Sad'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# Using camera Integrated Camera ...
# 10293

# %%
#Scared
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 10524
images_required = 10794
directory = 'testing_demo_4\\Sad'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Using camera Integrated Camera ...
# 10537

# %%
#Scared
import pygame.camera
import pygame.image
import sys
import numpy as np
import os

flag_collecting = False
images_collected = 12296
images_required = 12481
directory = 'TEST_testing_demo_6\\Agony'

from keras_preprocessing.image import save_img
import keyboard

pygame.camera.init()


cameras = pygame.camera.list_cameras()
 
print("Using camera %s ..." % cameras[0])
 
webcam = pygame.camera.Camera(cameras[0])
webcam.set_controls(hflip = True, vflip = False)
webcam.start()

img = webcam.get_image()
 
WIDTH = img.get_width()
HEIGHT = img.get_height()
 
screen = pygame.display.set_mode( ( WIDTH, HEIGHT ) )
pygame.display.set_caption("pygame Camera View")

while True :
    
    pygame.display.update()
    
    if images_collected == images_required:
        pygame.quit()
        break
    
    for e in pygame.event.get() :
        if e.type == pygame.QUIT:
            pygame.quit()
            
            
    screen.blit(img, (0,0))
    img = webcam.get_image()
    
    frame = np.rot90(np.array(img.get_view('3')), 3)
    pygame.draw.rect(img, (0,0,0), pygame.Rect((200, 100), (240, 240)), 2)
    
    
    if flag_collecting == True:
        sliced_frame = frame[100:340, 200:440]
        save_path = os.path.join(directory, '{}.jpg'.format(images_collected + 1))

        save_img(save_path, np.fliplr(sliced_frame))
        images_collected += 1
    
    if keyboard.is_pressed('a'):
        flag_collecting = not flag_collecting
    
    if keyboard.is_pressed('q'):
        print(images_collected)
        pygame.quit()
        break
# Out:
# Using camera Integrated Camera ...
# 12311

# %%
 # !pip install keyboard

# %%
from pynput.keyboard import Key, Listener

def on_press(key):
    print('{0} pressed'.format(
        key))

def on_release(key):
    print('{0} release'.format(
        key))
    if key == Key.esc:
        # Stop listener
        return False

# Collect events until released
with Listener(
        on_press=on_press,
        on_release=on_release) as listener:
# Out:
# Key.enter release
# Key.ctrl_l release
# 'f' pressed
# 'f' release
# 'w' pressed
# 'w' release
# 'c' pressed
# 'c' release
# 'f' pressed
# 'f' release
# Key.esc pressed
# Key.esc release
