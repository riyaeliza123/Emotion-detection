# %%
from keras.models import load_model
from tensorflow.keras.utils import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

# %%
face_classifier=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
classifier = load_model(r'C:\Users\hp\face_sentiment_mark2_train_test.h5')

class_labels=['Neutral', 'Happy', 'Sad', 'Scared', 'Agony']

# %%
cap=cv2.VideoCapture(0)

while True:
    ret,frame=cap.read()
    labels=[]
    #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=face_classifier.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = frame[y:y+h,x:x+w]
        roi_gray=cv2.resize(roi_gray,(240,240),interpolation=cv2.INTER_AREA)

        if np.sum([roi_gray])!=0:
            
            prediction = classifier.predict(np.array([roi_gray]))
            label = class_labels[np.argmax(prediction)]

            #preds=classifier.predict(roi)[0]
            #label=class_labels[preds.argmax()]
            label_position=(x-w,y)
            cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
            print(label)
        else:
            cv2.putText(frame,'No Face Found',(20,20),cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
    
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/3089793987.py in <module>
#       5     labels=[]
#       6     #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ----> 7     faces=face_classifier.detectMultiScale(gray,1.3,5)
#       8
#       9     for (x,y,w,h) in faces:
#
# NameError: name 'gray' is not defined

# %%
cap=cv2.VideoCapture(0)

while True:
    ret,frame=cap.read()
    labels=[]
    cv2.rectangle(frame,(100,200),(340,440),(255,0,0),2)
    
    roi_gray = frame[100:340, 200:440] 
    prediction = classifier.predict(np.array([roi_gray]))
    label = class_labels[np.argmax(prediction)]
    label_position=(100,100)
    cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
    print(label)
    
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Agony
# 1/1 [==============================] - 0s 156ms/step
# Agony
# 1/1 [==============================] - 0s 79ms/step
# Agony
# 1/1 [==============================] - 0s 113ms/step
# Agony
# 1/1 [==============================] - 0s 97ms/step
# Agony
# 1/1 [==============================] - 0s 81ms/step
# Agony
# 1/1 [==============================] - 0s 94ms/step
# Agony
# 1/1 [==============================] - 0s 79ms/step
# Agony
# 1/1 [==============================] - 0s 86ms/step
# Agony
# 1/1 [==============================] - 0s 81ms/step
# Agony
# 1/1 [==============================] - 0s 84ms/step
# Agony
# 1/1 [==============================] - 0s 73ms/step
# Agony
# 1/1 [==============================] - 0s 74ms/step
# Happy
# 1/1 [==============================] - 0s 82ms/step
# Agony
# 1/1 [==============================] - 0s 91ms/step
# Happy
# 1/1 [==============================] - 0s 81ms/step
# Happy
# ...

# %%
roi_gray
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [203,  11,  12],
#         ...,
#         [182,  59,  58],
#         [203,  46,  45],
#         [255,   0,   0]],
#
#        ...,
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [135,  13,  16],
#         ...,
#         [  8,   5,   8],
#         [ 70,   4,   6],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [164,   8,  11],
#         ...,
#         [ 69,   4,   6],
#         [116,   3,   5],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
# ...
